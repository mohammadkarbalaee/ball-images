# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
ok = cv2.imread('transparent.png', cv2.IMREAD_UNCHANGED)
not_ok = cv2.imread('./balls/1.png', cv2.IMREAD_UNCHANGED)

# %%
plt.imshow(cv2.cvtColor(ok, cv2.COLOR_BGRA2RGBA))

# %%
plt.imshow(cv2.cvtColor(not_ok, cv2.COLOR_BGRA2RGBA))

# %%
print(ok[0,0])
# Out:
# [0 0 0 0]

# %%
print(not_ok[0,0])
# Out:
# [255 255 255   0]

# %%
for i in range(0, not_ok.shape[0]):
    for j in range(0, not_ok.shape[1]):
        if np.array_equal(not_ok[i, j], [255,255,255,0]):
            not_ok[i, j] = [0,0,0,0]

# %%
print(not_ok[0,0])
# Out:
# [0 0 0 0]

# %%
plt.imshow(cv2.cvtColor(not_ok, cv2.COLOR_BGRA2RGBA))

# %%
cv2.imwrite('new.png', not_ok)
# Out:
# True
